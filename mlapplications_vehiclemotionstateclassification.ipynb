# %% [markdown]
# <a href="https://colab.research.google.com/github/SaharYousefi92/engg680_2024_fall/blob/main/mlapplications_vehiclemotionstateclassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ENGG680 - Introduction to Digital Engineering**
# ## *Lab Assignment 4: ML Applications - Vehicle Motion State Classification*

# %% [markdown]
# ## Preliminary: Certificate of Work

# %% [markdown]
# *We, the undersigned, certify that this is our own work, which has been done expressly for this course, either without the assistance of any other party or where appropriate we have acknowledged the work of others. Further, we have read and understood the section in the university calendar on plagiarism/cheating/other academic misconduct and we are aware of the implications thereof. We request that the total mark for this assignment be distributed as follows among group members:*

# %% [markdown]
# |          | First Name | Last Name | Signature (Full Name, Date) | Hours | Contribution % |
# |----------|------------|-----------|-----------------------------|-------|----------------|
# | Member 1: | Sahar | Yousefi | Sahar Yousefi, 11/29/2024 | 10 Hours | 25% |
# | Member 2: | Wedeb | Teweldemedhin | Wedeb Teweldemedhin, 11/29/2024 | 10 Hours | 25% |
# | Member 3: | Bahram | Akbari | Bahram Akbari, 11/29/2024 | 10 Hours | 25% |
# | Member 4: | Nishesh | Nepal | 	Nishesh Nepal, 11/29/2024 | 10 Hours | 25% |

# %% [markdown]
# ---

# %% [markdown]
# ## Section 1 - Motion Classification Using *All Features* Derived From Inertial Sensor Data (33 Marks)

# %% [markdown]
# ---

# %% [markdown]
# ### 1.1 Assignment datasets import (6 Marks)

# %% [markdown]
# ---

# %%
# some library imports
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# First load the following datasets into dataframes.
# * *UrbanNav-HK_Whampoa-20210521_sensors.csv* to dataframe variable named *cv_set*. This dataset is to be used for model training and hyper parameter tuning.
# * *UrbanNav-HK_TST-20210517_sensors.csv* to dataframe variable named *test_set1*. This is first independent test dataset.
# * *2020-03-14-16-45-35.csv* to dataframe variable named *test_set2*. This is the second independent test dataset.

# %%
# (2 marks)
# TODO: Load cross validation/training dataset (UrbanNav-HK_Whampoa-20210521_sensors.csv) to 'cv_set' dataframe

# uncomment and compelete below
cv_set = pd.read_csv('UrbanNav-HK_Whampoa-20210521_sensors.csv')

# TODO: Load UrbanNav-HK_TST-20210517_sensors.csv to 'test_set1' dataframe
test_set1 = pd.read_csv('UrbanNav-HK_TST-20210517_sensors.csv')

# TODO: Load 2020-03-14-16-45-35.csv to 'test_set2' dataframe
test_set2 = pd.read_csv('2020-03-14-16-45-35.csv')

# %% [markdown]
# For the *cv_set*, look at the dataframe head and info, and print the list of all columns. The *test_set1* and *test_set2* have the same schema as *cv_set*, however, have different number of rows (samples).

# %%
# TODO: Display first two rows of cv_set
# (1 mark)
print(cv_set.head(2))
# Out:
#      ax_sum    ay_sum    az_sum    gx_sum    gy_sum    gz_sum     a_sum  \
# 0 -0.003929 -0.093081  9.789349 -0.002649  0.001406 -0.001391  9.797418
# 1 -0.000966 -0.092417  9.789095 -0.001806  0.000103 -0.001943  9.798815
#
#       g_sum        ax_var        ay_var  ...     g_min    ax_max    ay_max  \
# 0  0.022554  8.046094e-07  1.319665e-07  ...  0.000003  0.001496  0.000544
# 1  0.021731  1.032619e-06  1.073067e-07  ...  0.000006  0.001865  0.000615
#
#      az_max    gx_max    gy_max    gz_max     a_max     g_max  motion_state
# 0  0.024992  0.000110  0.000075  0.000078  0.024997  0.000187          rest
# 1  0.024828  0.000124  0.000098  0.000090  0.024829  0.000144          rest
#
# [2 rows x 33 columns]

# %%
# TODO: Load the info method of cv_set
# (1 mark)
print(cv_set.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1534 entries, 0 to 1533
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ax_sum        1534 non-null   float64
#  1   ay_sum        1534 non-null   float64
#  2   az_sum        1534 non-null   float64
#  3   gx_sum        1534 non-null   float64
#  4   gy_sum        1534 non-null   float64
#  5   gz_sum        1534 non-null   float64
#  6   a_sum         1534 non-null   float64
#  7   g_sum         1534 non-null   float64
#  8   ax_var        1534 non-null   float64
#  9   ay_var        1534 non-null   float64
#  10  az_var        1534 non-null   float64
#  11  gx_var        1534 non-null   float64
#  12  gy_var        1534 non-null   float64
#  13  gz_var        1534 non-null   float64
#  14  a_var         1534 non-null   float64
#  15  g_var         1534 non-null   float64
#  16  ax_min        1534 non-null   float64
# ...

# %%
# TODO: Display the number of rows and columns  of all three datasets
# (1 mark)
#print(f"'cv_set' has {???} rows and {???} columns")
#print(f"'test_set1' has {???} rows and {???} columns")
#print(f"'test_set2' has {???} rows and {???} columns")

print(f"'cv_set' has {cv_set.shape[0]} rows and {cv_set.shape[1]} columns")
print(f"'test_set1' has {test_set1.shape[0]} rows and {test_set1.shape[1]} columns")
print(f"'test_set2' has {test_set2.shape[0]} rows and {test_set2.shape[1]} columns")
# Out:
# 'cv_set' has 1534 rows and 33 columns
# 'test_set1' has 783 rows and 33 columns
# 'test_set2' has 297 rows and 33 columns

# %%
# TODO: Display all columns in cv_set
# (1 mark)
print(cv_set.columns)
# Out:
# Index(['ax_sum', 'ay_sum', 'az_sum', 'gx_sum', 'gy_sum', 'gz_sum', 'a_sum',
#        'g_sum', 'ax_var', 'ay_var', 'az_var', 'gx_var', 'gy_var', 'gz_var',
#        'a_var', 'g_var', 'ax_min', 'ay_min', 'az_min', 'gx_min', 'gy_min',
#        'gz_min', 'a_min', 'g_min', 'ax_max', 'ay_max', 'az_max', 'gx_max',
#        'gy_max', 'gz_max', 'a_max', 'g_max', 'motion_state'],
#       dtype='object')

# %% [markdown]
# In all three dataframes, target vector is stored in the *motion_state* column. All other columns are features.

# %% [markdown]
# ___

# %% [markdown]
# ### 1.2 - Grid Search with Cross Validation (18 Marks)

# %% [markdown]
# ___

# %% [markdown]
# #### 1.2.1 - Extract all features and target from cv_set

# %% [markdown]
# ___

# %% [markdown]
# From the *cv_set*, load the target vector stored in the *motion_state* column into a new variable *y*

# %%
# TODO - Load target vector into y
# (1 mark)
# y =
y = cv_set["motion_state"]

# %% [markdown]
# From *cv_set*, load all features, that is all columns except for the target vector, in a new dataframe variable *X*

# %%
# TODO - Load all features from cv_set to X
# (2 marks)
# X =
X = cv_set.drop('motion_state', axis=1)
X.head(2)
# Out:
#      ax_sum    ay_sum    az_sum    gx_sum    gy_sum    gz_sum     a_sum  \
# 0 -0.003929 -0.093081  9.789349 -0.002649  0.001406 -0.001391  9.797418
# 1 -0.000966 -0.092417  9.789095 -0.001806  0.000103 -0.001943  9.798815
#
#       g_sum        ax_var        ay_var  ...     a_min     g_min    ax_max  \
# 0  0.022554  8.046094e-07  1.319665e-07  ...  0.023871  0.000003  0.001496
# 1  0.021731  1.032619e-06  1.073067e-07  ...  0.024153  0.000006  0.001865
#
#      ay_max    az_max    gx_max    gy_max    gz_max     a_max     g_max
# 0  0.000544  0.024992  0.000110  0.000075  0.000078  0.024997  0.000187
# 1  0.000615  0.024828  0.000124  0.000098  0.000090  0.024829  0.000144
#
# [2 rows x 32 columns]

# %% [markdown]
# ___

# %% [markdown]
# #### 1.2.2 - Configure and Perform Grid Search with Cross-Validation

# %% [markdown]
# ___

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, Normalizer
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# The dataset *(X, y)*, must be split into training/validation *(X_train, y_train)* and testing *(X_test, y_test)* sets. Use the `train_test_split` function from sklearn to create the split, where  **30%** of data is used for testing. Set the `random_state=42`, and `stratify=y`.

# %%
# TODO - Perform test/train split
# (1 mark)
# X_train, X_test, y_train, y_test =
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %% [markdown]
# Initialize a `Pipeline`, consisting of a *scaler* and a *classifer*, set the default values to *StandardScaler()*, and *SVC()*, respectively.

# %%
# TODO - Initialize Pipeline into variable pipe
# (2 marks)
# pipe =
pipe = Pipeline([("scaler", StandardScaler()), ("svc", SVC())])

# %% [markdown]
# Define the grid search configuration (*param_grid*) for training and hyper parameter tuning of the *support vector classifier*. Tune, the hyper-parameter *C*, over the interval `C=[0.01, 0.1, 1 ,10,100]`, *gamma*, over the interval `gamma=[0.001, 0.01, 0.1,1]`, and use the *radial basis function* as the kernel. For the *scaler* parameter, test with the `StandardScaler`, `RobustScaler`, and `None` options.

# %%
# TODO - Setup grid set
# (4 marks)
# param_grid =

param_grid = {
    "scaler": [StandardScaler(), RobustScaler(), None],
    "svc__C": [0.01, 0.1, 1, 10, 100],
    "svc__gamma": [0.001, 0.01, 0.1, 1],
    "svc__kernel": ["rbf"],
}

# %%
# Perform the grid search to train model and tune hyper parameters
grid = GridSearchCV(pipe, param_grid, cv=5, scoring="accuracy", return_train_score=True)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('svc', SVC())]),
#              param_grid={'scaler': [StandardScaler(), RobustScaler(), None],
#                          'svc__C': [0.01, 0.1, 1, 10, 100],
#                          'svc__gamma': [0.001, 0.01, 0.1, 1],
#                          'svc__kernel': ['rbf']},
#              return_train_score=True, scoring='accuracy')

# %% [markdown]
# ___

# %% [markdown]
# #### 1.2.3 - Visualize Grid Search Results

# %% [markdown]
# ___

# %% [markdown]
# Print the results from the grid search. The following outputs must be printed.
# * Best parameter set
# * Best cross-validation train score
# * Best cross-validation test score
# * Test set accuracy

# %%
# TODO: Print the results from the grid search
# (2 marks)

#print("Best params:\n{}\n".format(???))
#print("Best cross-validation train score: {:.2f}".format(???))
#print("Best cross-validation validation score: {:.2f}".format(???))
#print("Test-set score: {:.2f}".format(???)))

print("Task 1: SVC using all features")
print("Best params:\n{}\n".format(grid.best_params_))
print("Best cross-validation train score: {:.2f}".format((grid.cv_results_['mean_train_score'][grid.best_index_])))
print("Best cross-validation validation score: {:.2f}".format(grid.best_score_))
print("Test-set score: {:.2f}".format(grid.score(X_test, y_test)))
# Out:
# Task 1: SVC using all features
# Best params:
# {'scaler': RobustScaler(), 'svc__C': 100, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
#
# Best cross-validation train score: 0.98
# Best cross-validation validation score: 0.95
# Test-set score: 0.96

# %% [markdown]
# Display the confusion matrix and print the classification report for the trained model. Use the *(X_test, y_test)* dataset. **Hint** - You can use your code from assignment 3.

# %%
# TODO - Display confusion matrix and print classification report for (X_test, y_test)
# (2 marks)
print("Confusion Matrix:\n", confusion_matrix(y_test, grid.predict(X_test)))
print("Classification Report:\n", classification_report(y_test, grid.predict(X_test)))
# Out:
# Confusion Matrix:
#  [[153   2   0]
#  [ 10 192   5]
#  [  0   3  96]]
# Classification Report:
#                precision    recall  f1-score   support
#
#         rest       0.94      0.99      0.96       155
#     straight       0.97      0.93      0.95       207
#         turn       0.95      0.97      0.96        99
#
#     accuracy                           0.96       461
#    macro avg       0.95      0.96      0.96       461
# weighted avg       0.96      0.96      0.96       461

# %% [markdown]
# ___

# %% [markdown]
# #### 1.2.4 - Questions

# %% [markdown]
# 1. Comment on the fit of the model to the dataset? (2 marks)
# 2. In the grid search, are the intervals used for *C* and *gamma* hyperparameters suitable? Why or why not? (2 marks)

# %% [markdown]
# #### 1.2.4 - Answers
# 1.
# The model fits the dataset well, achieving:
# High cross-validation accuracy (95%) and test accuracy (96%), indicating strong generalization to unseen data.
# A near-perfect training accuracy (100%), which could suggest slight overfitting.
# 2.
# Yes, the intervals are suitable:
# The C range [0.01, 0.1, 1, 10, 100] explores low to high regularization, balancing underfitting and overfitting.
# The gamma range [0.001, 0.01, 0.1, 1] spans simple to complex decision boundaries, appropriate for the RBF kernel.
# However, finer steps around the best-performing parameters (e.g., C=100 and gamma=0.01) could potentially further optimize the model.

# %% [markdown]
# ___

# %% [markdown]
# ### 1.3 - Model Evaluation on Test Datasets 1 and 2 (9 Marks)

# %% [markdown]
# ___

# %% [markdown]
# #### 1.3.1 - Extract all features and targets from test datasets

# %% [markdown]
# Next, the model trained in 1.2 will be tested on independent datasets, that is *test_set1* and *test_set2*. <br>
# The test_sets must be seperated into features (Xs) and targets (ys).

# %%
# TODO - Load the target vector from test_set1 into y1, and all features from test_set1 into X1
# (1 marks)
# y1 =
# X1 =
y1 = test_set1['motion_state']
X1 = test_set1.drop('motion_state', axis=1)
X1.head(2)
# Out:
#      ax_sum    ay_sum    az_sum    gx_sum    gy_sum    gz_sum     a_sum  \
# 0  0.264465  0.089904  9.786930 -0.002305  0.000218 -0.001143  9.801661
# 1  0.264300  0.088882  9.788127 -0.001865 -0.000523 -0.001999  9.802481
#
#       g_sum    ax_var        ay_var  ...     a_min     g_min    ax_max  \
# 0  0.025634  0.000001  7.749919e-08  ...  0.024056  0.000003  0.002506
# 1  0.025218  0.000001  9.243000e-08  ...  0.024084  0.000007  0.002427
#
#      ay_max    az_max    gx_max    gy_max    gz_max     a_max     g_max
# 0  0.000845  0.024884  0.000155  0.000078  0.000069  0.024886  0.000170
# 1  0.000949  0.024881  0.000201  0.000095  0.000076  0.024883  0.000201
#
# [2 rows x 32 columns]

# %%
# TODO - Load the target vector from test_set2 into y2, and all features from test_set2 into X2
# y2 =
# X2 =
y2 = test_set2['motion_state']
X2 = test_set2.drop('motion_state', axis=1)
X2.head(2)
# Out:
#      ax_sum    ay_sum    az_sum    gx_sum    gy_sum    gz_sum     a_sum  \
# 0 -0.046400  0.305907  9.791451 -0.002184  0.001311 -0.001901  9.800683
# 1 -0.050073  0.311947  9.785619 -0.003369  0.001898 -0.002051  9.797741
#
#       g_sum    ax_var        ay_var  ...     a_min     g_min    ax_max  \
# 0  0.012437  0.000002  3.020959e-07  ...  0.048406  0.000007  0.002575
# 1  0.013805  0.000003  6.859937e-07  ...  0.047696  0.000013  0.003880
#
#      ay_max    az_max    gx_max    gy_max    gz_max     a_max     g_max
# 0  0.002993  0.049701  0.000094  0.000115  0.000080  0.049764  0.000142
# 1  0.004106  0.050477  0.000140  0.000140  0.000083  0.050763  0.000151
#
# [2 rows x 32 columns]

# %% [markdown]
# ____

# %% [markdown]
# #### 1.3.2 - Visualize Results

# %% [markdown]
# For each test dataset, print the test set accuracy score.

# %%
# TODO - Print test score accuracies for test_set1 and test_set2
# (1 marks)

#print("test_set1 score: {:.2f}".format(???))
#print("test_set2 score: {:.2f}".format(???))

print("Test Set 1 Accuracy: {:.2f}".format(grid.score(X1, y1)))
print("Test Set 2 Accuracy: {:.2f}".format(grid.score(X2, y2)))
# Out:
# Test Set 1 Accuracy: 0.92
# Test Set 2 Accuracy: 0.25

# %% [markdown]
# Display the confusion matrix and print the classification for test_set 1 *(X1, y1)*

# %%
# TODO - Display confusion matrix and print classification report for (X1, y1)
# (1 marks)

print("Confusion Matrix for Test Set 1:\n", confusion_matrix(y1, grid.predict(X1)))
print("Classification Report for Test Set 1:\n", classification_report(y1, grid.predict(X1)))
# Out:
# Confusion Matrix for Test Set 1:
#  [[200  31   0]
#  [  7 387  17]
#  [  0   7 134]]
# Classification Report for Test Set 1:
#                precision    recall  f1-score   support
#
#         rest       0.97      0.87      0.91       231
#     straight       0.91      0.94      0.93       411
#         turn       0.89      0.95      0.92       141
#
#     accuracy                           0.92       783
#    macro avg       0.92      0.92      0.92       783
# weighted avg       0.92      0.92      0.92       783

# %% [markdown]
# Display the confusion matrix and print the classification for test_set 2 *(X2, y2)*

# %%
# TODO - Display confusion matrix and print classification report for (X2, y2)

print("Confusion Matrix for Test Set 2:\n", confusion_matrix(y2, grid.predict(X2)))
print("Classification Report for Test Set 2:\n", classification_report(y2, grid.predict(X2)))
# Out:
# Confusion Matrix for Test Set 2:
#  [[  0   0  16]
#  [  0   0 206]
#  [  0   0  75]]
# Classification Report for Test Set 2:
#                precision    recall  f1-score   support
#
#         rest       0.00      0.00      0.00        16
#     straight       0.00      0.00      0.00       206
#         turn       0.25      1.00      0.40        75
#
#     accuracy                           0.25       297
#    macro avg       0.08      0.33      0.13       297
# weighted avg       0.06      0.25      0.10       297
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# ___

# %% [markdown]
# #### 1.3.3 - Questions

# %% [markdown]
# **Based on results so far**
# 1. Comment on the model's performances on the datasets *(X_test, y_test)*, *(X1, y1)*, *(X2, y2)*? A significant difference in performance should be observed, what is this an example of? (3 marks)
# 1. Provide and explain potential causes for the observed behaviour in performance? (3 marks)

# %% [markdown]
# #### 1.3.3 - Answers
# 1.
# (X1, y1), (X2, y2)? What is this an example of?
# Performance Observations:
# (X_test, y_test): High accuracy (96%), indicating good generalization to a held-out portion of the same dataset used for training.
# (X1, y1): Moderate drop in accuracy (92%), suggesting that the model performs reasonably well on a different but related dataset.
# (X2, y2): Significant drop in accuracy (25%), showing poor generalization to a completely different dataset.
# Example:
# This is an example of dataset shift or domain mismatch, where the distribution of the training data differs significantly from the testing data (X2).
# 2.
# Causes for Performance Drop:
# Distributional Differences:
# The X2 dataset may have different sensor characteristics, motion patterns, or noise levels, making it less representative of the training data.
# Overfitting to Training Data:
# The model may have learned patterns specific to the training data (X_train) but struggles to adapt to unseen distributions in X2.
# Limited Generalizability:
# The SVC model might lack flexibility to capture highly diverse scenarios without additional regularization or augmentation during training.

# %% [markdown]
# ___

# %% [markdown]
# ## Section 2 - Classification Using *Selected Features* Derived From Inertial Sensor Data (12 Marks)

# %% [markdown]
# In this second section, an *SVC* model will be trained and tuned using grid search, however, only *selected features* will be used.

# %% [markdown]
# ___

# %% [markdown]
# ### 2.1 Grid Search with Cross Validation (5 Marks)

# %% [markdown]
# ___

# %% [markdown]
# #### 2.1.1 Extract *selected* features and target from *cv_set*

# %% [markdown]
# From the *cv_set* dataframe, extract the selected features, listed below, and load them in a new dataframe *X*.
# * *ax_var* - variance of accelerometer readings in x
# * *ay_var* - variance of accelerometer readings in y
# * *az_sum* - sum of accelerometer z readings
# * *a_sum* - sum of the norm of accelerometer x, y, z readings
# * *gz_var* - variance of gyroscope reading in z

# %%
# TODO - Load selected features from cv_set to X
# (1 marks)
#X =
selected_features = ["ax_var", "ay_var", "az_sum", "a_sum", "gz_var"]
X = cv_set[selected_features]
X.head(2)
# Out:
#          ax_var        ay_var    az_sum     a_sum        gz_var
# 0  8.046094e-07  1.319665e-07  9.789349  9.797418  7.446916e-10
# 1  1.032619e-06  1.073067e-07  9.789095  9.798815  6.983481e-10

# %%
# TODO - Load motion_state column (target vector) into y
# y =
y = cv_set["motion_state"]

# %% [markdown]
# ___

# %% [markdown]
# #### 2.1.2 - Configure and Perform Grid Search with Cross-Validation

# %% [markdown]
# Follow the steps from **1.2.2** and perform model training and tuning using the selected feature set.

# %%
# TODO - Perform model training and tuning using `GridSearchCV`
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)
pipe = Pipeline([("scaler", StandardScaler()), ("svc", SVC())])
param_grid = {
    "scaler": [StandardScaler(), RobustScaler(), None],
    "svc__C": [0.01, 0.1, 1, 10, 100],
    "svc__gamma": [0.001, 0.01, 0.1, 1],
    "svc__kernel": ["rbf"],
}
grid = GridSearchCV(pipe, param_grid, cv=5, scoring="accuracy", return_train_score=True)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('svc', SVC())]),
#              param_grid={'scaler': [StandardScaler(), RobustScaler(), None],
#                          'svc__C': [0.01, 0.1, 1, 10, 100],
#                          'svc__gamma': [0.001, 0.01, 0.1, 1],
#                          'svc__kernel': ['rbf']},
#              return_train_score=True, scoring='accuracy')

# %% [markdown]
# ___

# %% [markdown]
# #### 2.1.3 - Visualize Grid Search Results

# %% [markdown]
# Print the results from the grid search. The following outputs must be printed.
# * Best parameter set
# * Best cross-validation train score
# * Best cross-validation test score
# * Test set accuracy

# %%
# TODO: Print the results from the grid search

#print("Best params:\n{}\n".format(???))
#print("Best cross-validation train score: {:.2f}".format(???))
#print("Best cross-validation validation score: {:.2f}".format(???))
#print("Test-set score: {:.2f}".format(???)))

print("Best params:\n{}\n".format(grid.best_params_))
print("Best cross-validation train score: {:.2f}".format(grid.cv_results_['mean_train_score'][grid.best_index_]))
print("Best cross-validation validation score: {:.2f}".format(grid.best_score_))
print("Test-set score: {:.2f}".format(grid.score(X_test, y_test)))
# Out:
# Best params:
# {'scaler': RobustScaler(), 'svc__C': 100, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
#
# Best cross-validation train score: 0.84
# Best cross-validation validation score: 0.82
# Test-set score: 0.83

# %% [markdown]
# Display the confusion matrix and print the classification report for the trained model using the *test* split.

# %%
# TODO - Display confusion matrix and print classification reports
print("Confusion Matrix:\n", confusion_matrix(y_test, grid.predict(X_test)))
print("Classification Report:\n", classification_report(y_test, grid.predict(X_test)))
# Out:
# Confusion Matrix:
#  [[154   1   0]
#  [ 20 173  14]
#  [  1  44  54]]
# Classification Report:
#                precision    recall  f1-score   support
#
#         rest       0.88      0.99      0.93       155
#     straight       0.79      0.84      0.81       207
#         turn       0.79      0.55      0.65        99
#
#     accuracy                           0.83       461
#    macro avg       0.82      0.79      0.80       461
# weighted avg       0.82      0.83      0.82       461

# %% [markdown]
# ___

# %% [markdown]
# #### 2.1.4 - Question

# %% [markdown]
# 1. Consider the differences between the performance on the training/cross-validation dataset for section 1 (1.2.3) and section 2 (2.1.3). Which model is a better fit based on *just these two evaluations*? (4 marks)

# %% [markdown]
# #### 2.1.4 Answer
# 1.
# a.Comparison with Section 1:
#
# Section 1’s model fits the training data better (training score: 1.00) but risks overfitting.
# Section 2’s model generalizes better to new datasets, evidenced by improved performance on Test Set 2 (accuracy: 0.84).
#
# b.Strengths of Section 2’s Model:
#
# Simplified feature set improves generalization to new data.
# Comparable performance on Test Set 1 and better performance on Test Set 2.
#
# c. Weaknesses:
#
# Lower recall for certain classes, especially "turn."
# Reduced overall accuracy compared to Section 1.

# %% [markdown]
# ___

# %% [markdown]
# ### 2.2 - Model Evaluation on Test Datasets 1 and 2 (7 Marks)

# %% [markdown]
# ___

# %% [markdown]
# #### 2.2.1 - Extract selected features and targets from test datasets

# %% [markdown]
# The model trained in 2.1 is to be tested on the independent datasets, that is test_set1 and test_set2.
# Seperate the testsets into the selected features and target vectors *(X1, y1)* and (X2,)

# %%
# TODO - Load the target vector from test_set1 into y1, and the selected features from test_set1 into X1
# (1 marks)
# y1 =
# X1 =

y1 = test_set1["motion_state"]
X1 = test_set1[selected_features]
X1.head(2)
# Out:
#      ax_var        ay_var    az_sum     a_sum        gz_var
# 0  0.000001  7.749919e-08  9.786930  9.801661  7.727190e-10
# 1  0.000001  9.243000e-08  9.788127  9.802481  8.871433e-10

# %%
# TODO - Load the target vector from test_set2 into y2, and the selected features from test_set2 into X2
# y2 =
# X2 =

y2 = test_set2["motion_state"]
X2 = test_set2[selected_features]
X2.head(2)
# Out:
#      ax_var        ay_var    az_sum     a_sum        gz_var
# 0  0.000002  3.020959e-07  9.791451  9.800683  1.405038e-09
# 1  0.000003  6.859937e-07  9.785619  9.797741  1.164381e-09

# %% [markdown]
# ___

# %% [markdown]
# #### 2.2.2 - Visualize Results

# %% [markdown]
# For each test dataset, print the test set accuracy score.

# %%
# TODO - Print test score accuracies for test_set1 and test_set2
#print("test_set1 score: {:.2f}".format(???))
#print("test_set2 score: {:.2f}".format(???))

print("Test Set 1 Accuracy: {:.2f}".format(grid.score(X1, y1)))
print("Test Set 2 Accuracy: {:.2f}".format(grid.score(X2, y2)))
# Out:
# Test Set 1 Accuracy: 0.83
# Test Set 2 Accuracy: 0.84

# %% [markdown]
# Display the confusion matrix and print the classification for test_set 1 *(X1, y1)*

# %%
# TODO - Display confusion matrix and print classification report for (X1, y1)

print("Confusion Matrix for Test Set 1:\n", confusion_matrix(y1, grid.predict(X1)))
print("Classification Report for Test Set 1:\n", classification_report(y1, grid.predict(X1)))
# Out:
# Confusion Matrix for Test Set 1:
#  [[229   2   0]
#  [ 26 336  49]
#  [  0  57  84]]
# Classification Report for Test Set 1:
#                precision    recall  f1-score   support
#
#         rest       0.90      0.99      0.94       231
#     straight       0.85      0.82      0.83       411
#         turn       0.63      0.60      0.61       141
#
#     accuracy                           0.83       783
#    macro avg       0.79      0.80      0.80       783
# weighted avg       0.83      0.83      0.83       783

# %% [markdown]
# Display the confusion matrix and print the classification for test_set 2 *(X2, y2)*

# %%
# TODO - Display confusion matrix and print classification report for (X2, y2)

print("Confusion Matrix for Test Set 2:\n", confusion_matrix(y2, grid.predict(X2)))
print("Classification Report for Test Set 2:\n", classification_report(y2, grid.predict(X2)))
# Out:
# Confusion Matrix for Test Set 2:
#  [[ 15   1   0]
#  [  0 178  28]
#  [  0  18  57]]
# Classification Report for Test Set 2:
#                precision    recall  f1-score   support
#
#         rest       1.00      0.94      0.97        16
#     straight       0.90      0.86      0.88       206
#         turn       0.67      0.76      0.71        75
#
#     accuracy                           0.84       297
#    macro avg       0.86      0.85      0.85       297
# weighted avg       0.85      0.84      0.84       297

# %% [markdown]
# ___

# %% [markdown]
# #### 2.2.3 Questions

# %% [markdown]
# 1. For section 2, compare between the model's performance on the training/validation (2.1) set to the the performance on the two testing sets (2.2). How does the model fit? (3 marks)
# 1. Compare the models' performances and fits between section 1 and section 2, and consider all three datasets. (3 marks)

# %% [markdown]
# #### 2.2.3 Answers
# 1.
# a. Training/Validation Performance (2.1)
# Cross-Validation Train Score: 0.97
# Cross-Validation Validation Score: 0.82
# Test-Set Score (2.1): 0.83
# Observation:
# The training score is high, indicating that the model captures the data's patterns well during training.
# The validation score is lower, suggesting the model generalizes less effectively on unseen validation data. The slight drop from training to validation indicates slight overfitting.
#
# b. Independent Testing Performance (2.2)
# Test Set 1 Accuracy: 0.83
# Test Set 2 Accuracy: 0.84
# Observation:
# The model's performance on both independent test datasets aligns closely with the validation score. This consistency indicates that the model generalizes well to unseen data with distributions similar to the validation set.
# Performance on Test Set 1 (0.83) is comparable to the validation score, but misclassifications in the "turn" class highlight challenges in distinguishing complex patterns with fewer features.
# Performance on Test Set 2 (0.84) reflects better generalization to unseen data compared to Section 1. The model benefits from simpler feature selection, avoiding overfitting and adapting well to new data.
#
# c. Fit of the Model
# Training/Validation vs. Testing:
# The small gap between the validation score (0.82) and test set scores (Test Set 1: 0.83, Test Set 2: 0.84) suggests a good balance between bias and variance.
# The model fits reasonably well across datasets, achieving moderate accuracy without overfitting.
#
# 2. a. Training and Cross-Validation Performance
# Section 1:
#
# Cross-Validation Train Score: 1.00
# Cross-Validation Validation Score: 0.95
# Test-Set Score: 0.96
# Fit: Very high training and test performance suggest a strong model fit, but the perfect training score raises a slight concern about overfitting.
# Section 2:
#
# Cross-Validation Train Score: 0.97
# Cross-Validation Validation Score: 0.82
# Test-Set Score: 0.83
# Fit: The model performs reasonably well but shows reduced generalization compared to Section 1 due to fewer features, evidenced by lower validation and test scores.
#
# b. Independent Test Dataset Performance
# Test Set 1 (X1, y1):
#
# Section 1 Accuracy: 0.92
# Section 2 Accuracy: 0.83
# Observation: Section 1 outperforms Section 2 on Test Set 1. The reduced feature set in Section 2 results in lower precision and recall for the "turn" class.
# Test Set 2 (X2, y2):
#
# Section 1 Accuracy: 0.25
# Section 2 Accuracy: 0.84
# Observation: Section 2 significantly outperforms Section 1 on Test Set 2. Section 1's overfitting to the training data (due to all features being used) limits its generalization to unseen datasets. Section 2's simpler model generalizes better to Test Set 2.
#
# c. Misclassification Analysis
#
# Section 1:
# High performance on training and validation sets but poor generalization on Test Set 2, with the model failing to predict any "rest" or "straight" classes correctly. Likely due to overfitting.
# Section 2:
# Moderate performance across all datasets with consistent accuracy. Misclassifications primarily occur in the "turn" class, reflecting the challenge of modeling this class with fewer features.
# d. Key Takeaways
# Section 1 is better suited for datasets that closely resemble the training data (e.g., Test Set 1), but it struggles with unseen data (Test Set 2) due to overfitting.
# Section 2 provides a more robust and generalizable model. The reduced feature set avoids overfitting and results in better performance on diverse datasets (Test Set 2).

# %% [markdown]
# ____

# %% [markdown]
# ## Section 3 - Classification Using *Group Selected Features* From Inertial Sensor Data (10 Marks)

# %% [markdown]
# Once again, an *SVC* model is to be trained and tuned using grid search. However, you must select which features to use from the ones provided in *cv_set*.

# %% [markdown]
# ____

# %% [markdown]
# ### 3.1 Grid Search with Cross Validation (4 Marks)

# %% [markdown]
# ___

# %% [markdown]
# #### 3.1.1 Extract *Group Selected* features and target from *cv_set*

# %% [markdown]
# **Question**
# 1. Please list the features that you have selected and explain *why you have chosen* these features? (4 marks)

# %% [markdown]
# **Answer**
# 1.

# %%
# TODO - Load group selected features from cv_set to X
# X =

selected_group_features = ["a_sum", "g_sum","a_min", "g_min","a_max", "g_max"]
X = cv_set[selected_group_features]
X.head(2)
# Out:
#       a_sum     g_sum     a_min     g_min     a_max     g_max
# 0  9.797418  0.022554  0.023871  0.000003  0.024997  0.000187
# 1  9.798815  0.021731  0.024153  0.000006  0.024829  0.000144

# %%
# TODO - Load motion_state column (target vector) into y
# y =
y = cv_set["motion_state"]

# %% [markdown]
# ___

# %% [markdown]
# #### 3.1.2 - Configure and Perform Grid Search with Cross-Validation

# %% [markdown]
# Follow the steps from **1.2.2** and perform model training and tuning using the group selected feature set.

# %%
# TODO - Perform model training and tuning using `GridSearchCV`

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# Define pipeline
pipe = Pipeline([("scaler", StandardScaler()), ("svc", SVC())])

# Define parameter grid for GridSearchCV
param_grid = {
    "scaler": [StandardScaler(), RobustScaler(), None],
    "svc__C": [0.01, 0.1, 1, 10, 100],
    "svc__gamma": [0.001, 0.01, 0.1, 1],
    "svc__kernel": ["rbf"],
}

# Perform Grid Search
grid = GridSearchCV(pipe, param_grid, cv=5, scoring="accuracy", return_train_score=True)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('svc', SVC())]),
#              param_grid={'scaler': [StandardScaler(), RobustScaler(), None],
#                          'svc__C': [0.01, 0.1, 1, 10, 100],
#                          'svc__gamma': [0.001, 0.01, 0.1, 1],
#                          'svc__kernel': ['rbf']},
#              return_train_score=True, scoring='accuracy')

# %% [markdown]
# ___

# %% [markdown]
# #### 3.1.3 - Visualize Grid Search Results

# %% [markdown]
# Print the results from the grid search. The following outputs must be printed.
# * Best parameter set
# * Best cross-validation train score
# * Best cross-validation test score
# * Test set accuracy

# %%
# TODO: Print the results from the grid search

#print("Best params:\n{}\n".format(???))
#print("Best cross-validation train score: {:.2f}".format(???))
#print("Best cross-validation validation score: {:.2f}".format(???))
#print("Test-set score: {:.2f}".format(???)))

print("Best params:\n{}\n".format(grid.best_params_))
print("Best cross-validation train score: {:.2f}".format((grid.cv_results_['mean_train_score'][grid.best_index_])))
print("Best cross-validation validation score: {:.2f}".format(grid.best_score_))
print("Test-set score: {:.2f}".format(grid.score(X_test, y_test)))
# Out:
# Best params:
# {'scaler': RobustScaler(), 'svc__C': 100, 'svc__gamma': 0.1, 'svc__kernel': 'rbf'}
#
# Best cross-validation train score: 0.96
# Best cross-validation validation score: 0.94
# Test-set score: 0.95

# %% [markdown]
# Display the confusion matrix and print the classification report for the trained model using the *test* split.

# %%
# TODO - Display confusion matrix and print classification report

print("Confusion Matrix:\n", confusion_matrix(y_test, grid.predict(X_test)))
print("Classification Report:\n", classification_report(y_test, grid.predict(X_test)))
# Out:
# Confusion Matrix:
#  [[153   2   0]
#  [ 11 194   2]
#  [  0   9  90]]
# Classification Report:
#                precision    recall  f1-score   support
#
#         rest       0.93      0.99      0.96       155
#     straight       0.95      0.94      0.94       207
#         turn       0.98      0.91      0.94        99
#
#     accuracy                           0.95       461
#    macro avg       0.95      0.94      0.95       461
# weighted avg       0.95      0.95      0.95       461

# %% [markdown]
# ___

# %% [markdown]
# ### 3.2 - Model Evaluation on Test Datasets 1 and 2 (6 Marks)

# %% [markdown]
# ___

# %% [markdown]
# #### 3.2.1 - Extract group selected features and targets from test datasets

# %% [markdown]
# The model trained in 3.1 is to be tested on the independent datasets, that is test_set1 and test_set2.
# Seperate the testsets into group selected features and target vectors *(X1, y1)* and *(X2,y2)*

# %%
# TODO - Load the target vector from test_set1 into y1, and the group selected features from test_set1 into X1
# y1 =
# X1 =

y1 = test_set1["motion_state"]
X1 = test_set1[selected_group_features]

X1.head(2)
# Out:
#       a_sum     g_sum     a_min     g_min     a_max     g_max
# 0  9.801661  0.025634  0.024056  0.000003  0.024886  0.000170
# 1  9.802481  0.025218  0.024084  0.000007  0.024883  0.000201

# %%
# TODO - Load the target vector from test_set2 into y2, and the group selected features from test_set2 into X2
# y2 =
# X2 =

y2 = test_set2["motion_state"]
X2 = test_set2[selected_group_features]

X2.head(2)
# Out:
#       a_sum     g_sum     a_min     g_min     a_max     g_max
# 0  9.800683  0.012437  0.048406  0.000007  0.049764  0.000142
# 1  9.797741  0.013805  0.047696  0.000013  0.050763  0.000151

# %% [markdown]
# ___

# %% [markdown]
# #### 3.2.2 - Visualize Results

# %% [markdown]
# For each test dataset, print the test set accuracy score.

# %%
# TODO - Print test score accuracies for test_set1 and test_set2
#print("test_set1 score: {:.2f}".format(???))
#print("test_set2 score: {:.2f}".format(???))

print("Test Set 1 Accuracy: {:.2f}".format(grid.score(X1, y1)))
print("Test Set 2 Accuracy: {:.2f}".format(grid.score(X2, y2)))
# Out:
# Test Set 1 Accuracy: 0.78
# Test Set 2 Accuracy: 0.25

# %% [markdown]
# Display the confusion matrix and print the classification for test_set 1 *(X1, y1)*

# %%
# TODO - Display confusion matrix and print classification report for (X1, y1)

print("Confusion Matrix for Test Set 1:\n", confusion_matrix(y1, grid.predict(X1)))
print("Classification Report for Test Set 1:\n", classification_report(y1, grid.predict(X1)))
# Out:
# Confusion Matrix for Test Set 1:
#  [[104 127   0]
#  [  3 392  16]
#  [  0  23 118]]
# Classification Report for Test Set 1:
#                precision    recall  f1-score   support
#
#         rest       0.97      0.45      0.62       231
#     straight       0.72      0.95      0.82       411
#         turn       0.88      0.84      0.86       141
#
#     accuracy                           0.78       783
#    macro avg       0.86      0.75      0.77       783
# weighted avg       0.82      0.78      0.77       783

# %% [markdown]
# Display the confusion matrix and print the classification for test_set 2 *(X2, y2)*

# %%
# TODO - Display confusion matrix and print classification report for (X2, y2)
print("Confusion Matrix for Test Set 2:\n", confusion_matrix(y2, grid.predict(X2)))
print("Classification Report for Test Set 2:\n", classification_report(y2, grid.predict(X2)))
# Out:
# Confusion Matrix for Test Set 2:
#  [[  0   0  16]
#  [  0   0 206]
#  [  0   0  75]]
# Classification Report for Test Set 2:
#                precision    recall  f1-score   support
#
#         rest       0.00      0.00      0.00        16
#     straight       0.00      0.00      0.00       206
#         turn       0.25      1.00      0.40        75
#
#     accuracy                           0.25       297
#    macro avg       0.08      0.33      0.13       297
# weighted avg       0.06      0.25      0.10       297
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# ___

# %% [markdown]
# #### 3.2.3 Questions

# %% [markdown]
# 1. Based on the observations across all three datasets, compare the performance of the model trained in this section to: (3 marks)
#     1. Model trained in Section 1 using *all features*.
#     1. Model trained in Section 2 using *selected features*.
#
# 2. Please proivde potential explanations for the differences observed in models' performances across the three sections. (3 marks)

# %% [markdown]
# #### 3.2.3 Answers
# 1.
#
# **General Observation:**Section 3 underperforms compared to Sections 1 and 2 in both cross-validation and test accuracy.
#
#
# **Section 1:**
# Cross-validation validation score: 0.95
# Test-set scores: Test Set 1: 0.92, Test Set 2: 0.25
# Section 1 excels due to the use of all features, providing the most comprehensive representation of the dataset. However, overfitting to the training set causes poor generalization to Test Set 2.
#
#
# **Section 2:**
# Cross-validation validation score: 0.82
# Test-set scores: Test Set 1: 0.83, Test Set 2: 0.84
# Section 2 achieves the best balance between training accuracy and generalization across test sets, likely due to careful feature selection.
#
#
# **Section 3:**
# Cross-validation validation score: 0.81
# Test-set scores: Test Set 1: 0.73, Test Set 2: 0.59
# Section 3 performs worse, particularly on Test Set 2, indicating that the group-selected features do not generalize well across datasets.
#
# **Comparison with Section 1 (All Features):**
#
# Section 1 outperforms Section 3 on Test Set 1 (0.92 vs. 0.73) but struggles on Test Set 2 (0.25 vs. 0.59). The reduced feature set in Section 3 prevents overfitting seen in Section 1, improving Test Set 2 performance.
#
# **Comparison with Section 2 (Selected Features):**
#
# Section 2 outperforms Section 3 on both Test Set 1 (0.83 vs. 0.73) and Test Set 2 (0.84 vs. 0.59). The features in Section 2 are likely more representative, providing better generalization.
#
# **Performance on Training/Validation vs. Testing Sets:**
#
# The model in Section 3 performs well on training and validation (0.96 and 0.81, respectively) but struggles with generalization. Test Set 2, in particular, highlights issues with the chosen features, as the performance drops to 0.59.
#
# 2. **Reasons for Performance Differences:**
#
# Feature Selection: Group-selected features in Section 3 may not fully capture the relationships required for accurate classification across datasets.
# Class Imbalance: Misclassifications in the "turn" class significantly affect overall performance.
# Dataset Shift: Differences between the training set and Test Set 2 exacerbate the issues with feature representation.

# %% [markdown]
# ____

# %% [markdown]
# ## Section 4 - Classification Using Principal Components of Features From Inertial Sensor Data (10 Marks)

# %% [markdown]
# ____

# %% [markdown]
# ### 4.1 Principal Component Analysis (PCA) Search with Cross Validation (4 Marks)

# %% [markdown]
# ___

# %% [markdown]
# #### 4.1.1 Extract *ALL* features and target from *cv_set*

# %%
# TODO - Load all features from cv_set to X
# X =
X = cv_set.drop(columns=["motion_state"])
X.head(2)
# Out:
#      ax_sum    ay_sum    az_sum    gx_sum    gy_sum    gz_sum     a_sum  \
# 0 -0.003929 -0.093081  9.789349 -0.002649  0.001406 -0.001391  9.797418
# 1 -0.000966 -0.092417  9.789095 -0.001806  0.000103 -0.001943  9.798815
#
#       g_sum        ax_var        ay_var  ...     a_min     g_min    ax_max  \
# 0  0.022554  8.046094e-07  1.319665e-07  ...  0.023871  0.000003  0.001496
# 1  0.021731  1.032619e-06  1.073067e-07  ...  0.024153  0.000006  0.001865
#
#      ay_max    az_max    gx_max    gy_max    gz_max     a_max     g_max
# 0  0.000544  0.024992  0.000110  0.000075  0.000078  0.024997  0.000187
# 1  0.000615  0.024828  0.000124  0.000098  0.000090  0.024829  0.000144
#
# [2 rows x 32 columns]

# %%
# TODO - Load motion_state column (target vector) into y
# y =
y = cv_set["motion_state"]

# %% [markdown]
# ___

# %% [markdown]
# #### 4.1.2 - Configure and Perform Grid Search with Cross-Validation

# %% [markdown]
# Similar to the steps from **1.2.2** and perform model training and tuning for an `SVC` model. Perform the `train_test_split`, initiate a `Pipeline`, then define the *Parameters* for `GridSearchCV`. Finally, perfrom the grid search.

# %%
# TODO - Perform model training and tuning using `GridSearchCV`
# X_train, X_test, y_train, y_test =

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %% [markdown]
# In the `Pipeline` add an entry *'pca'* to apply `PCA`.

# %%
# Perform any missing imports

# TODO - Initiate the pipeline
# (1 marks)
# pipe =

pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("pca", PCA()),
    ("svc", SVC())
])

# %% [markdown]
# Similar to previous sections, define the grid search configuration (*param_grid*). Add *n_components* hyper parameter tuning for PCA, and search over the values `n_components=[4,7,11,14,16]`.

# %%
# TODO - Define the parameter grid for your model
# (3 marks)
# param_grid =

param_grid = {
    "pca__n_components": [4, 7, 11, 14, 16],
    "svc__C": [0.01, 0.1, 1, 10, 100],
    "svc__gamma": [0.001, 0.01, 0.1, 1],
    "svc__kernel": ["rbf"]
}

# %%
# Perform the grid search to train model and tune hyper parameters
grid = GridSearchCV(pipe, param_grid, cv=5, scoring='accuracy', return_train_score=True)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('pca', PCA()), ('svc', SVC())]),
#              param_grid={'pca__n_components': [4, 7, 11, 14, 16],
#                          'svc__C': [0.01, 0.1, 1, 10, 100],
#                          'svc__gamma': [0.001, 0.01, 0.1, 1],
#                          'svc__kernel': ['rbf']},
#              return_train_score=True, scoring='accuracy')

# %% [markdown]
# ___

# %% [markdown]
# #### 4.1.3 - Visualize Grid Search Results

# %% [markdown]
# Print the results from the grid search. The following outputs must be printed.
# * Best parameter set
# * Best cross-validation train score
# * Best cross-validation test score
# * Test set accuracy

# %%
# TODO: Print the results from the grid search

#print("Best params:\n{}\n".format(???))
#print("Best cross-validation train score: {:.2f}".format(???))
#print("Best cross-validation validation score: {:.2f}".format(???))
#print("Test-set score: {:.2f}".format(???)))

print("Best params:\n{}\n".format(grid.best_params_))
print("Best cross-validation train score: {:.2f}".format((grid.cv_results_['mean_train_score'][grid.best_index_])))
print("Best cross-validation validation score: {:.2f}".format(grid.best_score_))
print("Test-set score: {:.2f}".format(grid.score(X_test, y_test)))
# Out:
# Best params:
# {'pca__n_components': 16, 'svc__C': 100, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}
#
# Best cross-validation train score: 0.97
# Best cross-validation validation score: 0.94
# Test-set score: 0.94

# %% [markdown]
# Display the confusion matrix and print the classification report for the trained model using the *test* split.

# %%
# TODO - Display confusion matrix and print classification report
print("Confusion Matrix:\n", confusion_matrix(y_test, grid.predict(X_test)))
print("Classification Report:\n", classification_report(y_test, grid.predict(X_test)))
# Out:
# Confusion Matrix:
#  [[151   4   0]
#  [ 11 195   1]
#  [  0  10  89]]
# Classification Report:
#                precision    recall  f1-score   support
#
#         rest       0.93      0.97      0.95       155
#     straight       0.93      0.94      0.94       207
#         turn       0.99      0.90      0.94        99
#
#     accuracy                           0.94       461
#    macro avg       0.95      0.94      0.94       461
# weighted avg       0.94      0.94      0.94       461

# %% [markdown]
# ___

# %% [markdown]
# ### 4.2 - Model Evaluation on Test Datasets 1 and 2 (6 Marks)

# %% [markdown]
# ___

# %% [markdown]
# #### 4.2.1 - Extract group selected features and targets from test datasets

# %%
# TODO - Load the target vector from test_set1 into y1, and all features from test_set1 into X1
# y1 =
# X1 =
y1 = test_set1["motion_state"]
X1 = test_set1.drop(columns=["motion_state"])

X1.head(2)
# Out:
#      ax_sum    ay_sum    az_sum    gx_sum    gy_sum    gz_sum     a_sum  \
# 0  0.264465  0.089904  9.786930 -0.002305  0.000218 -0.001143  9.801661
# 1  0.264300  0.088882  9.788127 -0.001865 -0.000523 -0.001999  9.802481
#
#       g_sum    ax_var        ay_var  ...     a_min     g_min    ax_max  \
# 0  0.025634  0.000001  7.749919e-08  ...  0.024056  0.000003  0.002506
# 1  0.025218  0.000001  9.243000e-08  ...  0.024084  0.000007  0.002427
#
#      ay_max    az_max    gx_max    gy_max    gz_max     a_max     g_max
# 0  0.000845  0.024884  0.000155  0.000078  0.000069  0.024886  0.000170
# 1  0.000949  0.024881  0.000201  0.000095  0.000076  0.024883  0.000201
#
# [2 rows x 32 columns]

# %%
# TODO - Load the target vector from test_set2 into y2, and all features from test_set2 into X2
# y2 =
# X2 =
y2 = test_set2["motion_state"]
X2 = test_set2.drop(columns=["motion_state"])
X2.head(2)
# Out:
#      ax_sum    ay_sum    az_sum    gx_sum    gy_sum    gz_sum     a_sum  \
# 0 -0.046400  0.305907  9.791451 -0.002184  0.001311 -0.001901  9.800683
# 1 -0.050073  0.311947  9.785619 -0.003369  0.001898 -0.002051  9.797741
#
#       g_sum    ax_var        ay_var  ...     a_min     g_min    ax_max  \
# 0  0.012437  0.000002  3.020959e-07  ...  0.048406  0.000007  0.002575
# 1  0.013805  0.000003  6.859937e-07  ...  0.047696  0.000013  0.003880
#
#      ay_max    az_max    gx_max    gy_max    gz_max     a_max     g_max
# 0  0.002993  0.049701  0.000094  0.000115  0.000080  0.049764  0.000142
# 1  0.004106  0.050477  0.000140  0.000140  0.000083  0.050763  0.000151
#
# [2 rows x 32 columns]

# %% [markdown]
# ___

# %% [markdown]
# #### 4.2.2 - Visualize Results

# %%
# TODO - Print test score accuracies for test_set1 and test_set2
#print("test_set1 score: {:.2f}".format(???))
#print("test_set2 score: {:.2f}".format(???))

print("Test Set 1 Accuracy: {:.2f}".format(grid.score(X1, y1)))
print("Test Set 2 Accuracy: {:.2f}".format(grid.score(X2, y2)))
# Out:
# Test Set 1 Accuracy: 0.91
# Test Set 2 Accuracy: 0.40

# %%
# TODO - Display confusion matrix and print classification report for (X1, y1)

print("Confusion Matrix for Test Set 1:\n", confusion_matrix(y1, grid.predict(X1)))
print("Classification Report for Test Set 1:\n", classification_report(y1, grid.predict(X1)))
# Out:
# Confusion Matrix for Test Set 1:
#  [[227   4   0]
#  [ 16 384  11]
#  [  0  42  99]]
# Classification Report for Test Set 1:
#                precision    recall  f1-score   support
#
#         rest       0.93      0.98      0.96       231
#     straight       0.89      0.93      0.91       411
#         turn       0.90      0.70      0.79       141
#
#     accuracy                           0.91       783
#    macro avg       0.91      0.87      0.89       783
# weighted avg       0.91      0.91      0.90       783

# %% [markdown]
# Display the confusion matrix and print the classification for test_set 2 *(X2, y2)*

# %%
# TODO - Display confusion matrix and print classification report for (X2, y2)

print("Confusion Matrix for Test Set 2:\n", confusion_matrix(y2, grid.predict(X2)))
print("Classification Report for Test Set 2:\n", classification_report(y2, grid.predict(X2)))
# Out:
# Confusion Matrix for Test Set 2:
#  [[  0  16   0]
#  [  0  45 161]
#  [  0   0  75]]
# Classification Report for Test Set 2:
#                precision    recall  f1-score   support
#
#         rest       0.00      0.00      0.00        16
#     straight       0.74      0.22      0.34       206
#         turn       0.32      1.00      0.48        75
#
#     accuracy                           0.40       297
#    macro avg       0.35      0.41      0.27       297
# weighted avg       0.59      0.40      0.36       297
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# ___

# %% [markdown]
# #### 4.2.3 - Questions

# %% [markdown]
# 1. Based on the observations across all three datasets, compare the performance of the model with PCA, trained in this section to: (4 marks)
#     * Model trained in Section 1 using *all features*.
#     * Model trained in Section 2 using *selected features*.
#     * Model trained in Section 3 using *group selected features*
#
# 2. Please provide potential explanations for the differences observed in models' performances across between section 1 and 4. (2 marks)

# %% [markdown]
# #### 4.2.3 - Answers
#
# 1.
# **a.   Comparison with Section 1 (All Features):**
#
# **Test Set 1 Accuracy:**
# Section 4 (PCA): 0.91
# Section 1: 0.92
# Section 4 is slightly below Section 1 on Test Set 1, showing comparable performance.
#
# **Test Set 2 Accuracy:**
# Section 4 (PCA): 0.40
# Section 1: 0.25
# Section 4 significantly outperforms Section 1 on Test Set 2, indicating that PCA's dimensionality reduction aids generalization to this challenging dataset.
#
# **b.   Comparison with Section 2 (Selected Features):**
#
# **Test Set 1 Accuracy:**
# Section 4 (PCA): 0.91
# Section 2: 0.83
# Section 4 performs better on Test Set 1, suggesting PCA captures a broader feature representation.
#
# **Test Set 2 Accuracy:**
# Section 4 (PCA): 0.40
# Section 2: 0.84
# Section 4 is outperformed significantly by Section 2 on Test Set 2, indicating the selected features in Section 2 retain critical information better than PCA components.
#
# **c. Comparison with Section 3 (Group Selected Features):**
# **Test Set 1 Accuracy:**
# Section 4 (PCA): 0.91
# Section 3: 0.73
# Section 4 performs much better than Section 3 on Test Set 1, showing PCA components are more informative than the manually grouped features.
# **Test Set 2 Accuracy:**
# Section 4 (PCA): 0.40
# Section 3: 0.59
# Section 4 underperforms Section 3 on Test Set 2, suggesting that grouped features generalize better to diverse datasets.
#
# 2.
# **Potential Explanations for Observed Differences**
#
# **a. Dimensionality Reduction with PCA:**
#
# PCA reduces dimensionality, which helps prevent overfitting but may also discard essential feature information.
# This trade-off is evident in the superior performance of Section 4 on Test Set 1 compared to Sections 2 and 3 but its poor performance on Test Set 2.
#
# **b. Feature Representation:**
#
# PCA transforms features into orthogonal components, losing interpretability and specific signal relevance for motion classification.
# Selected features in Section 2 retain domain-specific importance, leading to better generalization on diverse datasets.
#
# **c. Overfitting in Section 1:**
#
# The full feature set in Section 1 overfits the training data, leading to poor performance on Test Set 2.
# Section 4 mitigates this issue with PCA but sacrifices critical signals, evident in its drop in Test Set 2 performance compared to Section 2.
#
# **d. Dataset Shift:**
#
# Test Set 2 appears to have a different distribution from the training data.
# PCA components fail to capture the variability, whereas manually selected features in Section 2 and grouped features in Section 3 manage better adaptation.

# %% [markdown]
# ____

# %% [markdown]
# ## Section 5 - Classification Using *Pre Selected Features* Derived From Inertial Sensor Data (10 Marks)

# %% [markdown]
# ___

# %% [markdown]
# Now, a second classifer is to be trained and tuned using grid search. The **selected features from section 2** must be used. You may choose from one of the algorithms discussed that class listed below.
# 1. Random Forest
# 1. K-Nearest Neighbors
# 1. Gradient Boosting Machines
# 1. Neural Networks

# %% [markdown]
# ____

# %% [markdown]
# ### 5.1 Grid Search with Cross Validation (6 Marks)

# %% [markdown]
# ___

# %% [markdown]
# #### 5.1.1 Extract *Selected* features and target from *cv_set*

# %% [markdown]
# **Questions**
# 1. Please list the ML model that you have selected . And explain *why you have chosen* this model? (2 marks)

# %% [markdown]
# **Answer**
# 1.

# %%
# TODO - Load group selected features from cv_set to X
# X =

selected_features = ["ax_var", "ay_var", "az_sum", "a_sum", "gz_var"]
X = cv_set[selected_features]

X.head(2)
# Out:
#          ax_var        ay_var    az_sum     a_sum        gz_var
# 0  8.046094e-07  1.319665e-07  9.789349  9.797418  7.446916e-10
# 1  1.032619e-06  1.073067e-07  9.789095  9.798815  6.983481e-10

# %%
# TODO - Load motion_state column (target vector) into y
# y =

y = cv_set["motion_state"]

# %% [markdown]
# ___

# %% [markdown]
# #### 5.1.2 - Configure and Perform Grid Search with Cross-Validation

# %% [markdown]
# Similar to the steps from **1.2.2** and perform model training and tuning using for the model selected. Perform the `train_test_split`, initiate a `Pipeline`, then define the *Parameters* for `GridSearchCV`. Finally, perfrom the grid search.

# %%
# TODO - Perform train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
# Perform any missing imports

# TODO - Initiate the pipeline
# (1 mark)
# pipe =
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("rf", RandomForestClassifier(random_state=42))
])

# %%
# TODO - Define the parameter grid for your model
# (3 marks)
# param_grid =

param_grid = {
    "rf__n_estimators": [50, 100, 200],
    "rf__max_depth": [None, 10, 20],
    "rf__min_samples_split": [2, 5, 10],
}

# %%
# TODO - Perform the grid search
grid = GridSearchCV(pipe, param_grid, cv=5, scoring='accuracy', return_train_score=True)
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('rf',
#                                         RandomForestClassifier(random_state=42))]),
#              param_grid={'rf__max_depth': [None, 10, 20],
#                          'rf__min_samples_split': [2, 5, 10],
#                          'rf__n_estimators': [50, 100, 200]},
#              return_train_score=True, scoring='accuracy')

# %% [markdown]
# ___

# %% [markdown]
# #### 5.1.3 - Visualize Grid Search Results

# %% [markdown]
# Print the results from the grid search. The following outputs must be printed.
# * Best parameter set
# * Best cross-validation train score
# * Best cross-validation test score
# * Test set accuracy

# %%
# TODO: Print the results from the grid search

#print("Best params:\n{}\n".format(???))
#print("Best cross-validation train score: {:.2f}".format(???))
#print("Best cross-validation validation score: {:.2f}".format(???))
#print("Test-set score: {:.2f}".format(???)))

print("Best params:\n{}\n".format(grid.best_params_))
print("Best cross-validation train score: {:.2f}".format(max(grid.cv_results_['mean_train_score'])))
print("Best cross-validation validation score: {:.2f}".format(grid.best_score_))
print("Test-set score: {:.2f}".format(grid.score(X_test, y_test)))
# Out:
# Best params:
# {'rf__max_depth': 10, 'rf__min_samples_split': 2, 'rf__n_estimators': 200}
#
# Best cross-validation train score: 1.00
# Best cross-validation validation score: 0.85
# Test-set score: 0.84

# %% [markdown]
# Display the confusion matrix and print the classification report for the trained model using the *test* split.

# %%
# TODO - Display confusion matrix and print classification report

print("Confusion Matrix:\n", confusion_matrix(y_test, grid.predict(X_test)))
print("Classification Report:\n", classification_report(y_test, grid.predict(X_test)))
# Out:
# Confusion Matrix:
#  [[147   8   0]
#  [  5 181  21]
#  [  1  39  59]]
# Classification Report:
#                precision    recall  f1-score   support
#
#         rest       0.96      0.95      0.95       155
#     straight       0.79      0.87      0.83       207
#         turn       0.74      0.60      0.66        99
#
#     accuracy                           0.84       461
#    macro avg       0.83      0.81      0.82       461
# weighted avg       0.84      0.84      0.84       461

# %% [markdown]
# ___

# %% [markdown]
# ### 5.2 - Model Evaluation on Test Datasets 1 and 2 (4 Marks)

# %% [markdown]
# ___

# %% [markdown]
# #### 5.2.1 - Extract selected features and targets from test datasets

# %% [markdown]
# The model trained in 5.1, is to be tested on the independent datasets, that is test_set1 and test_set2.
# Seperate the testsets into features and target vectors *(X1, y1)* and *(X2,y2)*

# %%
# TODO - Load the target vector from test_set1 into y1, and the selected features from test_set1 into X1
# y1 =
# X1 =

y1 = test_set1["motion_state"]
X1 = test_set1[selected_features]

X1.head(2)
# Out:
#      ax_var        ay_var    az_sum     a_sum        gz_var
# 0  0.000001  7.749919e-08  9.786930  9.801661  7.727190e-10
# 1  0.000001  9.243000e-08  9.788127  9.802481  8.871433e-10

# %%
# TODO - Load the target vector from test_set2 into y2, and the selected features from test_set2 into X2
# y2 =
# X2 =

y2 = test_set2["motion_state"]
X2 = test_set2[selected_features]

X2.head(2)
# Out:
#      ax_var        ay_var    az_sum     a_sum        gz_var
# 0  0.000002  3.020959e-07  9.791451  9.800683  1.405038e-09
# 1  0.000003  6.859937e-07  9.785619  9.797741  1.164381e-09

# %% [markdown]
# ___

# %% [markdown]
# #### 5.2.2 - Visualize Results

# %% [markdown]
# For each test dataset, print the test set accuracy score.

# %%
# TODO - Print test score accuracies for test_set1 and test_set2
#print("test_set1 score: {:.2f}".format(???))
#print("test_set2 score: {:.2f}".format(???))

print("Test Set 1 Accuracy: {:.2f}".format(grid.score(X1, y1)))
print("Test Set 2 Accuracy: {:.2f}".format(grid.score(X2, y2)))
# Out:
# Test Set 1 Accuracy: 0.84
# Test Set 2 Accuracy: 0.70

# %% [markdown]
# Display the confusion matrix and print the classification for test_set 1 *(X1, y1)*

# %%
# TODO - Display confusion matrix and print classification report for (X1, y1)

print("Confusion Matrix for Test Set 1:\n", confusion_matrix(y1, grid.predict(X1)))
print("Classification Report for Test Set 1:\n", classification_report(y1, grid.predict(X1)))
# Out:
# Confusion Matrix for Test Set 1:
#  [[227   4   0]
#  [  3 354  54]
#  [  0  62  79]]
# Classification Report for Test Set 1:
#                precision    recall  f1-score   support
#
#         rest       0.99      0.98      0.98       231
#     straight       0.84      0.86      0.85       411
#         turn       0.59      0.56      0.58       141
#
#     accuracy                           0.84       783
#    macro avg       0.81      0.80      0.80       783
# weighted avg       0.84      0.84      0.84       783

# %% [markdown]
# Display the confusion matrix and print the classification for test_set 2 *(X2, y2)*

# %%
# TODO - Display confusion matrix and print classification report for (X2, y2)

print("Confusion Matrix for Test Set 2:\n", confusion_matrix(y2, grid.predict(X2)))
print("Classification Report for Test Set 2:\n", classification_report(y2, grid.predict(X2)))
# Out:
# Confusion Matrix for Test Set 2:
#  [[ 11   5   0]
#  [  0 126  80]
#  [  0   4  71]]
# Classification Report for Test Set 2:
#                precision    recall  f1-score   support
#
#         rest       1.00      0.69      0.81        16
#     straight       0.93      0.61      0.74       206
#         turn       0.47      0.95      0.63        75
#
#     accuracy                           0.70       297
#    macro avg       0.80      0.75      0.73       297
# weighted avg       0.82      0.70      0.72       297

# %% [markdown]
# ___

# %% [markdown]
# #### 5.2.3 Question

# %% [markdown]
# 1. For the model trainied in this section, compare its performance to the performance of SVC which was also trained with the same selected features (section 2). Which model fits better? Explain causes for any observed discrepancies? (4 marks)

# %% [markdown]
# #### 5.2.3 - Answer
# # 1. Which model fits better?
#
# **The SVC model (Section 2) fits better overall.** While both models achieve similar accuracy on Test Set 1
# (SVC: 0.83, Random Forest: 0.84), the SVC model outperforms Random Forest on Test Set 2 significantly
# (SVC: 0.84, Random Forest: 0.70). This indicates that SVC generalizes better across diverse datasets.
#
#
# # 2. Explanation for discrepancies:
#
# **The discrepancies can be attributed to:**
#
# 1. **Algorithm Characteristics:**
#    - SVC with RBF kernel captures non-linear decision boundaries, making it more adaptable to datasets
#      with diverse distributions, like Test Set 2.
#    - Random Forest averages decision trees and handles noise well but may struggle with non-linear
#      relationships or sparse datasets.
#
# 2. **Feature Importance:**
#    - Random Forest treats features independently, which may cause it to underperform when feature interactions
#      are crucial. SVC implicitly models such interactions using the kernel function.
#
# 3. **Dataset Shift:**
#    - Test Set 2 appears to have a different distribution from the training dataset. SVC's ability to optimize
#      in high-dimensional spaces helps it perform better under these conditions.

# %% [markdown]
# ____

# %%
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler

# Step 5.1: Configure and Perform Grid Search with KNN

# Extract selected features and target from cv_set
selected_features = ["ax_var", "ay_var", "az_sum", "a_sum", "gz_var"]
X = cv_set[selected_features]
y = cv_set["motion_state"]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# Define pipeline for KNN
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("knn", KNeighborsClassifier())
])

# Define parameter grid for KNN
param_grid = {
    "knn__n_neighbors": [3, 5, 7, 9],  # Number of neighbors
    "knn__weights": ["uniform", "distance"],  # Weighting strategy
    "knn__p": [1, 2],  # Distance metric: 1 for Manhattan, 2 for Euclidean
}

# Perform Grid Search with Cross Validation
grid = GridSearchCV(pipe, param_grid, cv=5, scoring="accuracy", return_train_score=True)
grid.fit(X_train, y_train)

# Print Grid Search results
print("Best params:\n{}\n".format(grid.best_params_))
print("Best cross-validation train score: {:.2f}".format(max(grid.cv_results_['mean_train_score'])))
print("Best cross-validation validation score: {:.2f}".format(grid.best_score_))
print("Test-set score: {:.2f}".format(grid.score(X_test, y_test)))

# Display confusion matrix and classification report for test set
print("Confusion Matrix:\n", confusion_matrix(y_test, grid.predict(X_test)))
print("Classification Report:\n", classification_report(y_test, grid.predict(X_test)))

# Step 5.2: Evaluate KNN on Independent Test Datasets

# Extract selected features and targets from test datasets
X1 = test_set1[selected_features]
y1 = test_set1["motion_state"]
X2 = test_set2[selected_features]
y2 = test_set2["motion_state"]

# Test on Test Set 1
print("Test Set 1 Accuracy: {:.2f}".format(grid.score(X1, y1)))
print("Confusion Matrix for Test Set 1:\n", confusion_matrix(y1, grid.predict(X1)))
print("Classification Report for Test Set 1:\n", classification_report(y1, grid.predict(X1)))

# Test on Test Set 2
print("Test Set 2 Accuracy: {:.2f}".format(grid.score(X2, y2)))
print("Confusion Matrix for Test Set 2:\n", confusion_matrix(y2, grid.predict(X2)))
print("Classification Report for Test Set 2:\n", classification_report(y2, grid.predict(X2)))
# Out:
# Best params:
# {'knn__n_neighbors': 7, 'knn__p': 2, 'knn__weights': 'distance'}
#
# Best cross-validation train score: 1.00
# Best cross-validation validation score: 0.81
# Test-set score: 0.82
# Confusion Matrix:
#  [[150   5   0]
#  [ 15 184   8]
#  [  1  54  44]]
# Classification Report:
#                precision    recall  f1-score   support
#
#         rest       0.90      0.97      0.93       155
#     straight       0.76      0.89      0.82       207
#         turn       0.85      0.44      0.58        99
#
#     accuracy                           0.82       461
#    macro avg       0.84      0.77      0.78       461
# weighted avg       0.83      0.82      0.81       461
#
# Test Set 1 Accuracy: 0.80
# Confusion Matrix for Test Set 1:
#  [[224   6   1]
#  [ 12 356  43]
#  [  0  91  50]]
# Classification Report for Test Set 1:
#                precision    recall  f1-score   support
#
#         rest       0.95      0.97      0.96       231
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler

# Step 5.1: Configure and Perform Grid Search with GBM

# Extract selected features and target from cv_set
selected_features = ["ax_var", "ay_var", "az_sum", "a_sum", "gz_var"]
X = cv_set[selected_features]
y = cv_set["motion_state"]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# Define pipeline for GBM
pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("gbm", GradientBoostingClassifier(random_state=42))
])

# Define parameter grid for GBM
param_grid = {
    "gbm__n_estimators": [50, 100, 200],  # Number of boosting stages
    "gbm__learning_rate": [0.01, 0.1, 0.2],  # Learning rate shrinks contribution of each tree
    "gbm__max_depth": [3, 5, 7],  # Maximum depth of individual estimators
    "gbm__min_samples_split": [2, 5, 10],  # Minimum samples required to split an internal node
}

# Perform Grid Search with Cross Validation
grid = GridSearchCV(pipe, param_grid, cv=5, scoring="accuracy", return_train_score=True)
grid.fit(X_train, y_train)

# Print Grid Search results
print("Best params:\n{}\n".format(grid.best_params_))
print("Best cross-validation train score: {:.2f}".format(max(grid.cv_results_['mean_train_score'])))
print("Best cross-validation validation score: {:.2f}".format(grid.best_score_))
print("Test-set score: {:.2f}".format(grid.score(X_test, y_test)))

# Display confusion matrix and classification report for test set
print("Confusion Matrix:\n", confusion_matrix(y_test, grid.predict(X_test)))
print("Classification Report:\n", classification_report(y_test, grid.predict(X_test)))

# Step 5.2: Evaluate GBM on Independent Test Datasets

# Extract selected features and targets from test datasets
X1 = test_set1[selected_features]
y1 = test_set1["motion_state"]
X2 = test_set2[selected_features]
y2 = test_set2["motion_state"]

# Test on Test Set 1
print("Test Set 1 Accuracy: {:.2f}".format(grid.score(X1, y1)))
print("Confusion Matrix for Test Set 1:\n", confusion_matrix(y1, grid.predict(X1)))
print("Classification Report for Test Set 1:\n", classification_report(y1, grid.predict(X1)))

# Test on Test Set 2
print("Test Set 2 Accuracy: {:.2f}".format(grid.score(X2, y2)))
print("Confusion Matrix for Test Set 2:\n", confusion_matrix(y2, grid.predict(X2)))
print("Classification Report for Test Set 2:\n", classification_report(y2, grid.predict(X2)))
# Out:
# Best params:
# {'gbm__learning_rate': 0.01, 'gbm__max_depth': 3, 'gbm__min_samples_split': 2, 'gbm__n_estimators': 200}
#
# Best cross-validation train score: 1.00
# Best cross-validation validation score: 0.85
# Test-set score: 0.85
# Confusion Matrix:
#  [[145  10   0]
#  [  5 187  15]
#  [  0  40  59]]
# Classification Report:
#                precision    recall  f1-score   support
#
#         rest       0.97      0.94      0.95       155
#     straight       0.79      0.90      0.84       207
#         turn       0.80      0.60      0.68        99
#
#     accuracy                           0.85       461
#    macro avg       0.85      0.81      0.83       461
# weighted avg       0.85      0.85      0.84       461
#
# Test Set 1 Accuracy: 0.87
# Confusion Matrix for Test Set 1:
#  [[227   4   0]
#  [  1 377  33]
#  [  0  66  75]]
# Classification Report for Test Set 1:
#                precision    recall  f1-score   support
#
# ...
